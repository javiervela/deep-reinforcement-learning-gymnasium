# %%
import gymnasium as gym
import cv2

from stable_baselines3 import DQN, PPO
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
# Create the CartPole-v1 environment
env = gym.make("CartPole-v1", render_mode="rgb_array")

# %%
# # Create Deep Q-Network
# model = DQN(
#     "MlpPolicy",
#     env,
#     learning_rate=1e-3, # default: 0.0001 # good: 1e-3
#     buffer_size=50_000, # default: 1_000_000 # good: 50_000
#     learning_starts=1000, # default: 100 # good: 1000
#     batch_size=32, # default: 32
#     tau=1.0, # default: 1.0
#     gamma=0.99, # default: 0.99
#     train_freq=4, # default: 4
#     target_update_interval=1000, # default: 10000 # good: 1000
#     exploration_fraction=0.1, # default: 0.1
#     exploration_final_eps=0.02, # default: 0.05 # good: 0.02
#     seed=42,
#     verbose=1,
#     tensorboard_log="../logs/exercise_1/dqn_tensorboard/",
# )
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=500, verbose=1)

eval_callback = EvalCallback(
    env,
    best_model_save_path="../logs/exercise_1/",
    log_path="../logs/exercise_1/",
    eval_freq=5_000,
    deterministic=True,
    render=False,
    n_eval_episodes=5,
    callback_on_new_best=stop_callback
)

# %%
# Create PPO model
model = PPO("MlpPolicy", env, seed=42, device="cpu", verbose=1, tensorboard_log="../logs/exercise_1/ppo_tensorboard/")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# Train model on the environment
TRAINING_TIMESTEPS = 1_000_000
model.learn(total_timesteps=TRAINING_TIMESTEPS, callback=[eval_callback])
# Out:
# Logging to ../logs/exercise_1/ppo_tensorboard/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22       |
# |    ep_rew_mean     | 22       |
# | time/              |          |
# |    fps             | 6584     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.6        |
# |    ep_rew_mean          | 24.6        |
# | time/                   |             |
# |    fps                  | 2941        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008349772 |
# |    clip_fraction        | 0.0965      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.00935     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.36        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 52.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 32.1       |
# |    ep_rew_mean          | 32.1       |
# | time/                   |            |
# |    fps                  | 2498       |
# |    iterations           | 3          |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01179982 |
# |    clip_fraction        | 0.0871     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.664     |
# |    explained_variance   | 0.0738     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 11.6       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0223    |
# |    value_loss           | 31.3       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.8        |
# |    ep_rew_mean          | 42.8        |
# | time/                   |             |
# |    fps                  | 2314        |
# |    iterations           | 4           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008947515 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.629      |
# |    explained_variance   | 0.252       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.5        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0226     |
# |    value_loss           | 48.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.5        |
# |    ep_rew_mean          | 54.5        |
# | time/                   |             |
# |    fps                  | 2222        |
# |    iterations           | 5           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008610738 |
# |    clip_fraction        | 0.0924      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.602      |
# |    explained_variance   | 0.341       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.6        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0203     |
# |    value_loss           | 55.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 70.2         |
# |    ep_rew_mean          | 70.2         |
# | time/                   |              |
# |    fps                  | 2164         |
# |    iterations           | 6            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0096224565 |
# |    clip_fraction        | 0.101        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.587       |
# |    explained_variance   | 0.554        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.5         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0227      |
# |    value_loss           | 46.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 87.2         |
# |    ep_rew_mean          | 87.2         |
# | time/                   |              |
# |    fps                  | 2123         |
# |    iterations           | 7            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0076920083 |
# |    clip_fraction        | 0.0792       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.599       |
# |    explained_variance   | 0.663        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.2         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0123      |
# |    value_loss           | 48.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 105         |
# |    ep_rew_mean          | 105         |
# | time/                   |             |
# |    fps                  | 2103        |
# |    iterations           | 8           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.002635438 |
# |    clip_fraction        | 0.0203      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.573      |
# |    explained_variance   | 0.484       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.1        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00462    |
# |    value_loss           | 63          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 123          |
# |    ep_rew_mean          | 123          |
# | time/                   |              |
# |    fps                  | 2081         |
# |    iterations           | 9            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0070004403 |
# |    clip_fraction        | 0.0689       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.574       |
# |    explained_variance   | 0.739        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.85         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00983     |
# |    value_loss           | 39.9         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 143        |
# |    ep_rew_mean          | 143        |
# | time/                   |            |
# |    fps                  | 2071       |
# |    iterations           | 10         |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.00955992 |
# |    clip_fraction        | 0.0988     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.572     |
# |    explained_variance   | 0.82       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.67       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0123    |
# |    value_loss           | 33.9       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 157          |
# |    ep_rew_mean          | 157          |
# | time/                   |              |
# |    fps                  | 2146         |
# |    iterations           | 11           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0073634973 |
# |    clip_fraction        | 0.0437       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.563       |
# |    explained_variance   | 0.792        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.97         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00284     |
# |    value_loss           | 29.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 175          |
# |    ep_rew_mean          | 175          |
# | time/                   |              |
# |    fps                  | 2212         |
# |    iterations           | 12           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0048645656 |
# |    clip_fraction        | 0.0327       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.545       |
# |    explained_variance   | 0.707        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.6         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00415     |
# |    value_loss           | 44.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 197         |
# |    ep_rew_mean          | 197         |
# | time/                   |             |
# |    fps                  | 2261        |
# |    iterations           | 13          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009707192 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.542      |
# |    explained_variance   | 0.883       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.433       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00926    |
# |    value_loss           | 8.89        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 214         |
# |    ep_rew_mean          | 214         |
# | time/                   |             |
# |    fps                  | 2316        |
# |    iterations           | 14          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.004734094 |
# |    clip_fraction        | 0.0423      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.528      |
# |    explained_variance   | 0.306       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.392       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00219    |
# |    value_loss           | 9.85        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 232         |
# |    ep_rew_mean          | 232         |
# | time/                   |             |
# |    fps                  | 2366        |
# |    iterations           | 15          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.005624825 |
# |    clip_fraction        | 0.0232      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.524      |
# |    explained_variance   | 0.415       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.173       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00434    |
# |    value_loss           | 2.08        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 250         |
# |    ep_rew_mean          | 250         |
# | time/                   |             |
# |    fps                  | 2410        |
# |    iterations           | 16          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.005457865 |
# |    clip_fraction        | 0.0383      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.54       |
# |    explained_variance   | 0.249       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0617      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00308    |
# |    value_loss           | 1.08        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 268          |
# |    ep_rew_mean          | 268          |
# | time/                   |              |
# |    fps                  | 2451         |
# |    iterations           | 17           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0037410508 |
# |    clip_fraction        | 0.0174       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.527       |
# |    explained_variance   | 0.579        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0489       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0035      |
# |    value_loss           | 0.706        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 286         |
# |    ep_rew_mean          | 286         |
# | time/                   |             |
# |    fps                  | 2489        |
# |    iterations           | 18          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.002284747 |
# |    clip_fraction        | 0.00713     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.518      |
# |    explained_variance   | 0.000891    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.02        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00354    |
# |    value_loss           | 31.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 304          |
# |    ep_rew_mean          | 304          |
# | time/                   |              |
# |    fps                  | 2524         |
# |    iterations           | 19           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0059371586 |
# |    clip_fraction        | 0.0409       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.504       |
# |    explained_variance   | -1.06        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0471       |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0056      |
# |    value_loss           | 0.422        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 320         |
# |    ep_rew_mean          | 320         |
# | time/                   |             |
# |    fps                  | 2484        |
# |    iterations           | 20          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.007085866 |
# |    clip_fraction        | 0.0649      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.5        |
# |    explained_variance   | 0.0128      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0124      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00561    |
# |    value_loss           | 0.203       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 337         |
# |    ep_rew_mean          | 337         |
# | time/                   |             |
# |    fps                  | 2490        |
# |    iterations           | 21          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.010018542 |
# |    clip_fraction        | 0.0752      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.497      |
# |    explained_variance   | 0.626       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0422      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00399    |
# |    value_loss           | 0.124       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 358          |
# |    ep_rew_mean          | 358          |
# | time/                   |              |
# |    fps                  | 2520         |
# |    iterations           | 22           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0064017195 |
# |    clip_fraction        | 0.0532       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.482       |
# |    explained_variance   | 0.441        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0354       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00183     |
# |    value_loss           | 0.0745       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 374        |
# |    ep_rew_mean          | 374        |
# | time/                   |            |
# |    fps                  | 2548       |
# |    iterations           | 23         |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.00821751 |
# |    clip_fraction        | 0.0912     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.476     |
# |    explained_variance   | 0.774      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0113     |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.00553   |
# |    value_loss           | 0.0517     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 390         |
# |    ep_rew_mean          | 390         |
# | time/                   |             |
# |    fps                  | 2575        |
# |    iterations           | 24          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.003396532 |
# |    clip_fraction        | 0.0264      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.486      |
# |    explained_variance   | 0.222       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0188      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.000691   |
# |    value_loss           | 0.0302      |
# -----------------------------------------
# /home/javier/.cache/pypoetry/virtualenvs/deep-reinforcement-learning-gymnasium-u3px5S1O-py3.13/lib/python3.13/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=50000, episode_reward=500.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 500         |
# |    mean_reward          | 500         |
# | time/                   |             |
# |    total_timesteps      | 50000       |
# | train/                  |             |
# |    approx_kl            | 0.006074584 |
# |    clip_fraction        | 0.0473      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.499      |
# |    explained_variance   | 0.518       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00375     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00194    |
# |    value_loss           | 0.0193      |
# -----------------------------------------
# New best mean reward!
# Stopping training because the mean reward 500.00  is above the threshold 500

# %%
def add_overlay(frame_rgb, step, total_reward):
    """
    Adds step count and cumulative reward to the frame.
    """
    # Convert to BGR for OpenCV
    frame_bgr = cv2.cvtColor(frame_rgb, cv2.COLOR_RGB2BGR)

    # Prepare text
    step_text = f"Step: {step}"
    reward_text = f"Reward: {total_reward:.1f}"

    # Add text to frame
    cv2.putText(frame_bgr, step_text, org=(10, 30),
                fontFace=cv2.FONT_HERSHEY_SIMPLEX, fontScale=1,
                color=(0, 255, 0), thickness=2)

    # Convert back to RGB
    return cv2.cvtColor(frame_bgr, cv2.COLOR_BGR2RGB)

# %%
MAX_STEPS = 500
success = False

observation, info = env.reset(seed=42)
frames = []
step_count = 0
cumulative_reward = 0

for _ in range(MAX_STEPS):
    frame = env.render()

    frame_with_overlay = add_overlay(frame, step=step_count + 1, total_reward=cumulative_reward)
    frames.append(frame_with_overlay)

    action, _ = model.predict(observation, deterministic=True)
    observation, reward, terminated, truncated, info = env.step(action)
    cumulative_reward += reward
    step_count += 1

    if terminated or truncated:
        break

if step_count == MAX_STEPS:
    success = True
    print("Successfully balanced pole for 500 steps.")
else:
    print(f"Failed with {step_count} steps. Retrying...")

env.close()
# Out:
# Successfully balanced pole for 500 steps.

# %%
# Crear el video a partir de los cuadros guardados
video_filename = "../videos/cartpole_dqn_policy.mp4"
height, width, _ = frames[0].shape  # Obtener dimensiones de los cuadros

# Configuración de salida para formato MP4
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
video = cv2.VideoWriter(video_filename, fourcc, 30.0, (width, height))

# Escribir cada cuadro en el video
for frame in frames:
    video.write(cv2.cvtColor(frame, cv2.COLOR_RGB2BGR))  # Convertir de RGB a BGR para OpenCV

# Liberar el objeto VideoWriter
video.release()

print(f"Video guardado como {video_filename}")
# Out:
# Video guardado como ../videos/cartpole_dqn_policy.mp4

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# Compressed video path
compressed_path = "../videos/cartpole_dqn_policy_compressed.mp4"

os.system(f"rm {compressed_path}")
os.system(f"ffmpeg -i {video_filename} -vcodec libx264 {compressed_path}")
# Show video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=800 controls>
      <source src="%s" type="video/mp4">
</video>""" % data_url)
# Out:
# rm: cannot remove '../videos/cartpole_dqn_policy_compressed.mp4': No such file or directory
# ffmpeg version n7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 14.2.1 (GCC) 20250207
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-frei0r --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libdav1d --enable-libdrm --enable-libdvdnav --enable-libdvdread --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgsm --enable-libharfbuzz --enable-libiec61883 --enable-libjack --enable-libjxl --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libplacebo --enable-libpulse --enable-librav1e --enable-librsvg --enable-librubberband --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpl --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-nvdec --enable-nvenc --enable-opencl --enable-opengl --enable-shared --enable-vapoursynth --enable-version3 --enable-vulkan
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../videos/cartpole_dqn_policy.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:16.67, start: 0.000000, bitrate: 366 kb/s
#   Stream #0:0[0x1](und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 600x400 [SAR 1:1 DAR 3:2], 364 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x56a267565a40] using SAR=1/1
# [libx264 @ 0x56a267565a40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x56a267565a40] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0x56a267565a40] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../videos/cartpole_dqn_policy_compressed.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf61.7.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 600x400 [SAR 1:1 DAR 3:2], q=2-31, 30 fps, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.100 libx264
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# [out#0/mp4 @ 0x56a267588ec0] video:99KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 6.711555%
# frame=  500 fps=0.0 q=-1.0 Lsize=     106KiB time=00:00:16.60 bitrate=  52.2kbits/s speed=76.4x
# [libx264 @ 0x56a267565a40] frame I:2     Avg QP:18.93  size:  2484
# [libx264 @ 0x56a267565a40] frame P:148   Avg QP:24.85  size:   309
# [libx264 @ 0x56a267565a40] frame B:350   Avg QP:31.56  size:   143
# [libx264 @ 0x56a267565a40] consecutive B-frames:  1.2% 14.8%  4.8% 79.2%
# [libx264 @ 0x56a267565a40] mb I  I16..4:  6.4% 89.7%  3.9%
# [libx264 @ 0x56a267565a40] mb P  I16..4:  0.5%  0.2%  0.1%  P16..4:  5.6%  0.3%  0.2%  0.0%  0.0%    skip:93.2%
# [libx264 @ 0x56a267565a40] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  2.3%  0.2%  0.1%  direct: 0.0%  skip:97.3%  L0:62.0% L1:36.8% BI: 1.1%
# [libx264 @ 0x56a267565a40] 8x8 transform intra:61.9% inter:9.4%
# [libx264 @ 0x56a267565a40] coded y,uvDC,uvAC intra: 7.0% 13.5% 11.4% inter: 0.2% 0.4% 0.3%
# [libx264 @ 0x56a267565a40] i16 v,h,dc,p: 39% 59%  1%  0%
# [libx264 @ 0x56a267565a40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 61% 11% 27%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x56a267565a40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 31% 12% 30%  8%  3%  2%  2% 10%  2%
# [libx264 @ 0x56a267565a40] i8c dc,h,v,p: 78%  5% 16%  1%
# [libx264 @ 0x56a267565a40] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x56a267565a40] ref P L0: 85.7%  0.8%  8.5%  5.1%
# [libx264 @ 0x56a267565a40] ref B L0: 78.9% 17.2%  3.9%
# [libx264 @ 0x56a267565a40] ref B L1: 91.9%  8.1%
# [libx264 @ 0x56a267565a40] kb/s:48.36
# <video width=800 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>
